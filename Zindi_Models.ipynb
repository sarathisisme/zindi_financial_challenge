# %%
# Import of relevant packages
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
import seaborn as sns

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, RobustScaler, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import roc_auc_score, mean_absolute_error
from sklearn.base import BaseEstimator, TransformerMixin
from imblearn.pipeline import make_pipeline as imb_pipe
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import RandomOverSampler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.feature_selection import mutual_info_classif

import joblib


# Set random seed 
RSEED = 42
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('data/Train.csv')  # Training dataset
test = pd.read_csv('data/Test.csv')  # Test dataset (no labels)
ss = pd.read_csv('data/SampleSubmission.csv')  # Sample submission format
variables = pd.read_csv('data/VariableDefinitions.csv')  # Data dictionary

# %% [markdown]
# ### Train test split

# %%
X = train.drop('bank_account', axis = 1)
y = train[['bank_account']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=RSEED)
# Show the results of the split
print ("Training set has {} samples.".format(X_train.shape[0]))
print ("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 17643 samples.
# Testing set has 5881 samples.

# %% [markdown]
# ### Cleaning

# %%
y_train['bank_account'] = y_train['bank_account'].map({'Yes': 1, 'No': 0})
y_test['bank_account'] = y_test['bank_account'].map({'Yes': 1, 'No': 0})

# %%
categorical_variables = ['country', 'year', 'location_type',
       'cellphone_access','gender_of_respondent', 'relationship_with_head', 'marital_status',
       'education_level', 'job_type']
numerical_variables = ['household_size', 'age_of_respondent']

# %%
def clean(df_in):
    df = df_in.copy(deep=True)
    df = df.drop('uniqueid', axis = 1)
    df[numerical_variables] = df[numerical_variables].astype(float)
    return df

# %%
X_train = clean(X_train)
X_test = clean(X_test)

# %% [markdown]
# ### Pipeline for data cleaning and feature engineering

# %%
categorical_steps = [('ohe', OneHotEncoder(drop = 'first',sparse_output=False))]
categorical_pipeline = Pipeline(steps=categorical_steps)
numerical_steps = [('scaler', RobustScaler())]
numerical_pipeline = Pipeline(steps=numerical_steps)
transformers = [('categorical_pipeline', categorical_pipeline, categorical_variables),
                  ('numerical_pipeline', numerical_pipeline, numerical_variables)]

preprocessor = ColumnTransformer(transformers=transformers,
                                         remainder = 'drop').set_output(transform='pandas')

# %%
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('categorical_pipeline',
#                                  Pipeline(steps=[('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False))]),
#                                  ['country', 'year', 'location_type',
#                                   'cellphone_access', 'gender_of_respondent',
#                                   'relationship_with_head', 'marital_status',
#                                   'education_level', 'job_type']),
#                                 ('numerical_pipeline',
#                                  Pipeline(steps=[('scaler', RobustScaler())]),
#                                  ['household_size', 'age_of_respondent'])])

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Random forest with random search

# %%
pipeline = ImbPipeline(steps=[
    ("preprocessor", preprocessor),
    ("sampler", RandomOverSampler(random_state=RSEED)),
    ("classifier", RandomForestClassifier(
        n_jobs=-1,
        random_state=RSEED
    ))
])

# %%
param_grid = [
    {
        "preprocessor__numerical_pipeline__scaler": [StandardScaler(), MinMaxScaler(), RobustScaler()],
        "sampler": [
            RandomOverSampler(random_state=RSEED, sampling_strategy={1: 15_000}),
            SMOTE(sampling_strategy={1:15_000}, random_state=RSEED),
            ImbPipeline([
                ("smote", SMOTE(sampling_strategy={1:15_000}, random_state=RSEED)),
                ("nearmiss", NearMiss())
            ])
        ],
        "classifier__n_estimators": [200, 300, 500],
        "classifier__max_depth": [None, 10, 20, 30],
        "classifier__min_samples_split": [2, 5, 10],
        "classifier__min_samples_leaf": [1, 2, 4],
        "classifier__max_features": ["sqrt", "log2"]
    }
]

# %%
random_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_grid,
    n_iter=50,
    scoring='neg_mean_absolute_error',
    cv=5,
    random_state=RSEED,
    n_jobs=-1,
    verbose=1
)

random_search.fit(X_train, y_train.iloc[:, 0])
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('categorical_pipeline',
#                                                                                Pipeline(steps=[('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               sparse_output=False))]),
#                                                                                ['country',
#                                                                                 'year',
#                                                                                 'location_type',
#                                                                                 'cellphone_access',
#                                                                                 'gender_of_respondent',
#                                                                                 'relationship_with_head',
#                                                                                 'marital_status',
#                                                                                 'education_level',
#                                                                                 'job_type']),
#                                                                               ('num...
#                                          'preprocessor__numerical_pipeline__scaler': [StandardScaler(),
#                                                                                       MinMaxScaler(),
#                                                                                       RobustScaler()],
#                                          'sampler': [RandomOverSampler(random_state=42,
#                                                                        sampling_strategy={1: 15000}),
#                                                      SMOTE(random_state=42,
#                                                            sampling_strategy={1: 15000}),
#                                                      Pipeline(steps=[('smote',
#                                                                       SMOTE(random_state=42,
#                                                                             sampling_strategy={1: 15000})),
#                                                                      ('nearmiss',
#                                                                       NearMiss())])]}],
#                    random_state=42, scoring='neg_mean_absolute_error',
#                    verbose=1)

# %%
rf_best_model = random_search.best_estimator_
print(rf_best_model)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('categorical_pipeline',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['country', 'year',
#                                                    'location_type',
#                                                    'cellphone_access',
#                                                    'gender_of_respondent',
#                                                    'relationship_with_head',
#                                                    'marital_status',
#                                                    'education_level',
#                                                    'job_type']),
#                                                  ('numerical_pipeline',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['household_size',
#                                                    'age_of_respondent'])])),
#                 ('sampler',
#                  SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('classifier',
#                  RandomForestClassifier(max_features='log2',
#                                         min_samples_split=10, n_estimators=300,
#                                         n_jobs=-1, random_state=42))])

# %%
y_test_pred_rf_rnd_hyp = rf_best_model.predict(X_test)
y_test_pred_rf_rnd_hyp_probs = rf_best_model.predict_proba(X_test)[:, 1]

# %%
print(f"Random forest with random tuning: MAE = {mean_absolute_error(y_test, y_test_pred_rf_rnd_hyp)}")
print(f"Random forest with random tuning: roc curve score = {roc_auc_score(y_test, y_test_pred_rf_rnd_hyp_probs)}")
# Out:
# Random forest with random tuning: MAE = 0.1435130079918381
# Random forest with random tuning: roc curve score = 0.8482788958776104

# %% [markdown]
# ### Random forest with grid search

# %%
pipeline = ImbPipeline(steps=[
    ("preprocessor", preprocessor),
    ("sampler", SMOTE(sampling_strategy={1:15_000}, random_state=RSEED)),
    ("classifier", RandomForestClassifier(
        n_jobs=-1,
        random_state=RSEED
    ))
])

# %%
param_grid = {
    "preprocessor__numerical_pipeline__scaler": [StandardScaler()],
    "classifier__n_estimators": [200, 300, 400],
    "classifier__max_depth": [None, 20, 30],
    "classifier__max_features": ["log2"],
    "classifier__min_samples_split": [5, 10, 15],
    "classifier__min_samples_leaf": [1, 2]
}

# %%
grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring="neg_mean_absolute_error", 
    cv=5,
    n_jobs=-1,
    verbose=2
)

grid_search.fit(X_train, y_train.iloc[:, 0])
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('categorical_pipeline',
#                                                                          Pipeline(steps=[('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         sparse_output=False))]),
#                                                                          ['country',
#                                                                           'year',
#                                                                           'location_type',
#                                                                           'cellphone_access',
#                                                                           'gender_of_respondent',
#                                                                           'relationship_with_head',
#                                                                           'marital_status',
#                                                                           'education_level',
#                                                                           'job_type']),
#                                                                         ('numerical...
#                                         RandomForestClassifier(n_jobs=-1,
#                                                                random_state=42))]),
#              n_jobs=-1,
#              param_grid={'classifier__max_depth': [None, 20, 30],
#                          'classifier__max_features': ['log2'],
#                          'classifier__min_samples_leaf': [1, 2],
#                          'classifier__min_samples_split': [5, 10, 15],
#                          'classifier__n_estimators': [200, 300, 400],
#                          'preprocessor__numerical_pipeline__scaler': [StandardScaler()]},
#              scoring='neg_mean_absolute_error', verbose=2)

# %%
rf_best_model2 = grid_search.best_estimator_
print(rf_best_model2)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('categorical_pipeline',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['country', 'year',
#                                                    'location_type',
#                                                    'cellphone_access',
#                                                    'gender_of_respondent',
#                                                    'relationship_with_head',
#                                                    'marital_status',
#                                                    'education_level',
#                                                    'job_type']),
#                                                  ('numerical_pipeline',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['household_size',
#                                                    'age_of_respondent'])])),
#                 ('sampler',
#                  SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('classifier',
#                  RandomForestClassifier(max_features='log2',
#                                         min_samples_split=5, n_estimators=400,
#                                         n_jobs=-1, random_state=42))])

# %%
y_test_pred_rf_grd_hyp = rf_best_model2.predict(X_test)
y_test_pred_rf_grd_hyp_probs = rf_best_model2.predict_proba(X_test)[:, 1]

# %%
print(f"Random forest with grid tuning: MAE = {mean_absolute_error(y_test, y_test_pred_rf_grd_hyp)}")
print(f"Random forest with grid tuning: roc curve score = {roc_auc_score(y_test, y_test_pred_rf_grd_hyp_probs)}")
# Out:
# Random forest with grid tuning: MAE = 0.14402312531882333
# Random forest with grid tuning: roc curve score = 0.8410260657322239

# %%
joblib.dump(rf_best_model2, "rf_model.joblib")
# Out:
# ['rf_model.joblib']

# %% [markdown]
# ### Adaboost without hyperparameter tuning

# %%
pipeline_ad = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1,
    class_weight='balanced'),
    random_state=RSEED))
])

# %%
pipeline_ad.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('categorical_pipeline',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['country', 'year',
#                                                    'location_type',
#                                                    'cellphone_access',
#                                                    'gender_of_respondent',
#                                                    'relationship_with_head',
#                                                    'marital_status',
#                                                    'education_level',
#                                                    'job_type']),
#                                                  ('numerical_pipeline',
#                                                   Pipeline(steps=[('scaler',
#                                                                    RobustScaler())]),
#                                                   ['household_size',
#                                                    'age_of_respondent'])])),
#                 ('classifier',
#                  AdaBoostClassifier(estimator=DecisionTreeClassifier(class_weight='balanced',
#                                                                      max_depth=1),
#                                     random_state=42))])

# %%
y_test_pred_ad = pipeline_ad.predict(X_test)
y_test_pred_ad_probs = pipeline_ad.predict_proba(X_test)[:, 1]

# %%
print(f"Adaboost MAE = {mean_absolute_error(y_test, y_test_pred_ad)}")
print(f"Adaboost roc curve score = {roc_auc_score(y_test, y_test_pred_ad_probs)}")
# Out:
# Adaboost MAE = 0.22309131100153035
# Adaboost roc curve score = 0.8607698014572105

# %% [markdown]
# ### Adaboost with hyperparameter tuning and oversampling

# %%
pipeline_ad = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", AdaBoostClassifier(estimator=DecisionTreeClassifier(),
    random_state=RSEED))
])

# %%
y_train.value_counts()
# Out:
# bank_account
# 0               15159
# 1                2484
# Name: count, dtype: int64

# %%
ros = RandomOverSampler(random_state=RSEED, sampling_strategy={1: 15_000}) 

# pipeline
ros_pipeline = imb_pipe(ros, pipeline_ad)

# %%
param_grid = {
    'pipeline__preprocessor__numerical_pipeline__scaler': [StandardScaler(), MinMaxScaler(), RobustScaler()],
    'pipeline__classifier__n_estimators': [100, 200, 300],
    'pipeline__classifier__learning_rate': [0.01, 0.1, 0.5, 1.0],
    'pipeline__classifier__estimator__min_samples_split' : np.arange(2, 8, 2),  
    'pipeline__classifier__estimator__max_depth': [1, 2]
}

# %%
random_search = RandomizedSearchCV(
    estimator=ros_pipeline,
    param_distributions=param_grid,
    n_iter=50,
    scoring='neg_mean_absolute_error',  # or recall, f1, roc_auc
    cv=5,
    random_state=RSEED,
    n_jobs=-1,
    verbose=1
)

# %%
random_search.fit(X_train, y_train.iloc[:, 0])
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('randomoversampler',
#                                               RandomOverSampler(random_state=42,
#                                                                 sampling_strategy={1: 15000})),
#                                              ('pipeline',
#                                               Pipeline(steps=[('preprocessor',
#                                                                ColumnTransformer(transformers=[('categorical_pipeline',
#                                                                                                 Pipeline(steps=[('ohe',
#                                                                                                                  OneHotEncoder(drop='first',
#                                                                                                                                sparse_output=False))]),
#                                                                                                 ['country',
#                                                                                                  'year',
#                                                                                                  'location_type',
#                                                                                                  'cellph...
#                    param_distributions={'pipeline__classifier__estimator__max_depth': [1,
#                                                                                        2],
#                                         'pipeline__classifier__estimator__min_samples_split': array([2, 4, 6]),
#                                         'pipeline__classifier__learning_rate': [0.01,
#                                                                                 0.1,
#                                                                                 0.5,
#                                                                                 1.0],
#                                         'pipeline__classifier__n_estimators': [100,
#                                                                                200,
#                                                                                300],
#                                         'pipeline__preprocessor__numerical_pipeline__scaler': [StandardScaler(),
#                                                                                                MinMaxScaler(),
#                                                                                                RobustScaler()]},
#                    random_state=42, scoring='neg_mean_absolute_error',
#                    verbose=1)

# %%
best_model = random_search.best_estimator_
print(best_model)
# Out:
# Pipeline(steps=[('randomoversampler',
#                  RandomOverSampler(random_state=42,
#                                    sampling_strategy={1: 15000})),
#                 ('pipeline',
#                  Pipeline(steps=[('preprocessor',
#                                   ColumnTransformer(transformers=[('categorical_pipeline',
#                                                                    Pipeline(steps=[('ohe',
#                                                                                     OneHotEncoder(drop='first',
#                                                                                                   sparse_output=False))]),
#                                                                    ['country',
#                                                                     'year',
#                                                                     'location_type',
#                                                                     'cellphone_access',
#                                                                     'gender_of_respondent',
#                                                                     'relationship_with_head',
#                                                                     'marital_status',
#                                                                     'education_level',
#                                                                     'job_type']),
#                                                                   ('numerical_pipeline',
#                                                                    Pipeline(steps=[('scaler',
#                                                                                     MinMaxScaler())]),
#                                                                    ['household_size',
#                                                                     'age_of_respondent'])])),
#                                  ('classifier',
#                                   AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=2,
#                                                                                       min_samples_split=6),
#                                                      learning_rate=0.5,
#                                                      n_estimators=300,
#                                                      random_state=42))]))])

# %%
y_test_pred_ad_rnd_hyp = best_model.predict(X_test)
y_test_pred_ad_rnd_hyp_probs = best_model.predict_proba(X_test)[:, 1]

# %%
print(f"Adaboost Random Oversample with tuning: MAE = {mean_absolute_error(y_test, y_test_pred_ad_rnd_hyp)}")
print(f"Adaboost Random Oversample with tuning: roc curve score = {roc_auc_score(y_test, y_test_pred_ad_rnd_hyp_probs)}")
# Out:
# Adaboost Random Oversample with tuning: MAE = 0.20625743921101852
# Adaboost Random Oversample with tuning: roc curve score = 0.868739549184442

# %%
#test_copy = test.copy(deep=True)
#test_copy = clean(test_copy)
#y_final_test = best_model.predict(test_copy)
# Create submission DataFrame
#submission = pd.DataFrame({"uniqueid": test["uniqueid"] + " x " + test["country"],
#                           "bank_account": y_final_test})
#submission.to_csv('first_submission1.csv', index = False)

# %% [markdown]
# ### Adaboost with hyperparameter tuning with oversampling as hyperparameter

# %%
pipeline = ImbPipeline(steps=[
    ("preprocessor", preprocessor),
    ("sampler", RandomOverSampler()),
    ("classifier", AdaBoostClassifier(
        estimator=DecisionTreeClassifier(max_depth=2,min_samples_split=6),
        random_state=RSEED
    ))
])

# %%
param_grid = [
    {
        'preprocessor__numerical_pipeline__scaler': [MinMaxScaler()],
        "sampler": [
            RandomOverSampler(random_state=RSEED, sampling_strategy={1: 15_000}),
            SMOTE(sampling_strategy={1:15_000}, random_state=RSEED),
            ImbPipeline([
                ("smote", SMOTE(sampling_strategy={1:15_000}, random_state=RSEED)),
                ("nearmiss", NearMiss())
            ])
        ],
        "classifier__n_estimators": [300, 400, 500],
        "classifier__learning_rate": [0.4, 0.5, 0.6]
    }
]

# %%
gs = GridSearchCV(
    pipeline,
    param_grid=param_grid,
    scoring='neg_mean_absolute_error',  # or f1, balanced_accuracy, etc.
    cv=5,
    n_jobs=-1,
    verbose=2
)

gs.fit(X_train, y_train.iloc[:, 0])
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('categorical_pipeline',
#                                                                          Pipeline(steps=[('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         sparse_output=False))]),
#                                                                          ['country',
#                                                                           'year',
#                                                                           'location_type',
#                                                                           'cellphone_access',
#                                                                           'gender_of_respondent',
#                                                                           'relationship_with_head',
#                                                                           'marital_status',
#                                                                           'education_level',
#                                                                           'job_type']),
#                                                                         ('numerical...
#                           'classifier__n_estimators': [300, 400, 500],
#                           'preprocessor__numerical_pipeline__scaler': [MinMaxScaler()],
#                           'sampler': [RandomOverSampler(random_state=42,
#                                                         sampling_strategy={1: 15000}),
#                                       SMOTE(random_state=42,
#                                             sampling_strategy={1: 15000}),
#                                       Pipeline(steps=[('smote',
#                                                        SMOTE(random_state=42,
#                                                              sampling_strategy={1: 15000})),
#                                                       ('nearmiss',
#                                                        NearMiss())])]}],
#              scoring='neg_mean_absolute_error', verbose=2)

# %%
best_model2 = gs.best_estimator_
print(best_model2)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('categorical_pipeline',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['country', 'year',
#                                                    'location_type',
#                                                    'cellphone_access',
#                                                    'gender_of_respondent',
#                                                    'relationship_with_head',
#                                                    'marital_status',
#                                                    'education_level',
#                                                    'job_type']),
#                                                  ('numerical_pipeline',
#                                                   Pipeline(steps=[('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['household_size',
#                                                    'age_of_respondent'])])),
#                 ('sampler',
#                  SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('classifier',
#                  AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=2,
#                                                                      min_samples_split=6),
#                                     learning_rate=0.5, n_estimators=300,
#                                     random_state=42))])

# %%
y_test_pred_ad_rnd3_hyp = best_model2.predict(X_test)
y_test_pred_ad_rnd3_hyp_probs = best_model2.predict_proba(X_test)[:, 1]

# %%
print(f"Adaboost SMOTE with tuning: MAE = {mean_absolute_error(y_test, y_test_pred_ad_rnd3_hyp)}")
print(f"Adaboost SMOTE with tuning: roc curve score = {roc_auc_score(y_test, y_test_pred_ad_rnd3_hyp_probs)}")
# Out:
# Adaboost SMOTE with tuning: MAE = 0.11647678966162217
# Adaboost SMOTE with tuning: roc curve score = 0.8621573877287229

# %%
joblib.dump(best_model2, "ad_model.joblib")
# Out:
# ['ad_model.joblib']

# %%
#test_copy = test.copy(deep=True)
#test_copy = clean(test_copy)
#y_final_test = best_model.predict(test_copy)
# Create submission DataFrame
#submission = pd.DataFrame({"uniqueid": test["uniqueid"] + " x " + test["country"],
#                           "bank_account": y_final_test})
#submission.to_csv('first_submission.csv', index = False)

# %% [markdown]
# ### XGBoost with Randomized search

# %%
pipeline = ImbPipeline(steps=[
    ("preprocessor", preprocessor),
    ("sampler", SMOTE(sampling_strategy={1:15_000}, random_state=RSEED)),
    ("classifier", XGBClassifier(
        objective="binary:logistic",
        eval_metric="logloss",
        use_label_encoder=False,
        random_state=RSEED
    ))
])

# %%
from scipy.stats import uniform, randint

param_dist = {
    "preprocessor__numerical_pipeline__scaler": [StandardScaler(), MinMaxScaler(), RobustScaler()],
    "classifier__n_estimators": randint(100, 600),
    "classifier__max_depth": randint(3, 10),
    "classifier__learning_rate": uniform(0.01, 0.2),
    "classifier__subsample": uniform(0.6, 0.4),
    "classifier__colsample_bytree": uniform(0.6, 0.4),
    "classifier__min_child_weight": randint(1, 10),
    "classifier__gamma": uniform(0, 0.5)
}

# %%
search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_dist,
    n_iter=50,
    scoring="neg_mean_absolute_error",
    cv=5,
    verbose=2,
    n_jobs=-1,
    random_state=RSEED
)

search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=5, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   9.4s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  18.6s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=10, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  13.3s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=10, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  18.1s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  18.8s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   9.1s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  17.1s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=10, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   8.0s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=10, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  16.3s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=15, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  11.9s
# [CV] END classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=15, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  15.9s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  17.4s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=10, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   8.2s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=10, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  16.9s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  12.0s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   8.9s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   7.8s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  15.7s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=10, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  11.3s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=10, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  15.7s
# [CV] END classifier__max_depth=20, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=15, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  11.4s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=5, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   9.9s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=5, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  13.1s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=10, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   9.8s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=10, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  12.9s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   9.3s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  12.0s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  16.6s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  12.1s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=10, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   8.9s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=10, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  12.1s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=15, classifier__n_estimators=200, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   9.1s
# [CV] END classifier__max_depth=30, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=15, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  11.7s
# [CV] END classifier__learning_rate=0.4, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=SMOTE(random_state=42, sampling_strategy={1: 15000}); total time=  13.5s
# [CV] END classifier__learning_rate=0.4, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=SMOTE(random_state=42, sampling_strategy={1: 15000}); total time=  19.4s
# [CV] END classifier__learning_rate=0.4, classifier__n_estimators=500, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=RandomOverSampler(random_state=42, sampling_strategy={1: 15000}); total time=  19.1s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=RandomOverSampler(random_state=42, sampling_strategy={1: 15000}); total time=  11.9s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=RandomOverSampler(random_state=42, sampling_strategy={1: 15000}); total time=  12.0s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=RandomOverSampler(random_state=42, sampling_strategy={1: 15000}); total time=  15.3s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=500, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=RandomOverSampler(random_state=42, sampling_strategy={1: 15000}); total time=  18.7s
# [CV] END classifier__learning_rate=0.5, classifier__n_estimators=500, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=SMOTE(random_state=42, sampling_strategy={1: 15000}); total time=  24.9s
# [CV] END classifier__learning_rate=0.6, classifier__n_estimators=300, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=SMOTE(random_state=42, sampling_strategy={1: 15000}); total time=  15.0s
# [CV] END classifier__learning_rate=0.6, classifier__n_estimators=400, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=RandomOverSampler(random_state=42, sampling_strategy={1: 15000}); total time=  15.5s
# [CV] END classifier__learning_rate=0.6, classifier__n_estimators=500, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=RandomOverSampler(random_state=42, sampling_strategy={1: 15000}); total time=  19.3s
# [CV] END classifier__learning_rate=0.6, classifier__n_estimators=500, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__learning_rate=0.6, classifier__n_estimators=500, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__learning_rate=0.6, classifier__n_estimators=500, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__learning_rate=0.6, classifier__n_estimators=500, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__learning_rate=0.6, classifier__n_estimators=500, preprocessor__numerical_pipeline__scaler=MinMaxScaler(), sampler=Pipeline(steps=[('smote', SMOTE(random_state=42, sampling_strategy={1: 15000})),
#                 ('nearmiss', NearMiss())]); total time=   0.0s
# [CV] END classifier__colsample_bytree=0.749816047538945, classifier__gamma=0.4753571532049581, classifier__learning_rate=0.15639878836228102, classifier__max_depth=7, classifier__min_child_weight=5, classifier__n_estimators=202, classifier__subsample=0.7783331011414365, preprocessor__numerical_pipeline__scaler=RobustScaler(); total time=  20.6s
# [CV] END classifier__colsample_bytree=0.6849356442713105, classifier__gamma=0.09091248360355031, classifier__learning_rate=0.046680901970686764, classifier__max_depth=6, classifier__min_child_weight=6, classifier__n_estimators=352, classifier__subsample=0.7727780074568463, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  29.8s
# [CV] END classifier__colsample_bytree=0.6185801650879991, classifier__gamma=0.3037724259507192, classifier__learning_rate=0.04410482473745831, classifier__max_depth=9, classifier__min_child_weight=2, classifier__n_estimators=487, classifier__subsample=0.9768807022739411, preprocessor__numerical_pipeline__scaler=MinMaxScaler(); total time= 1.0min
# [CV] END classifier__colsample_bytree=0.9233589392465844, classifier__gamma=0.15230688458668534, classifier__learning_rate=0.02953442280127678, classifier__max_depth=6, classifier__min_child_weight=7, classifier__n_estimators=527, classifier__subsample=0.798070764044508, preprocessor__numerical_pipeline__scaler=RobustScaler(); total time=  59.0s
# [CV] END classifier__colsample_bytree=0.6125253169822235, classifier__gamma=0.42114238729749925, classifier__learning_rate=0.09995082667395314, classifier__max_depth=4, classifier__min_child_weight=4, classifier__n_estimators=369, classifier__subsample=0.8909087983425683, preprocessor__numerical_pipeline__scaler=RobustScaler(); total time=  20.6s
# [CV] END classifier__colsample_bytree=0.6353970008207678, classifier__gamma=0.0979914312095726, classifier__learning_rate=0.019045457782107613, classifier__max_depth=7, classifier__min_child_weight=2, classifier__n_estimators=466, classifier__subsample=0.9314950036607718, preprocessor__numerical_pipeline__scaler=MinMaxScaler(); total time=  46.1s
# [CV] END classifier__colsample_bytree=0.679486272613669, classifier__gamma=0.0027610585618011996, classifier__learning_rate=0.17309228569096685, classifier__max_depth=3, classifier__min_child_weight=8, classifier__n_estimators=262, classifier__subsample=0.9160702162124823, preprocessor__numerical_pipeline__scaler=RobustScaler(); total time=  12.5s
# [CV] END classifier__colsample_bytree=0.679486272613669, classifier__gamma=0.0027610585618011996, classifier__learning_rate=0.17309228569096685, classifier__max_depth=3, classifier__min_child_weight=8, classifier__n_estimators=262, classifier__subsample=0.9160702162124823, preprocessor__numerical_pipeline__scaler=RobustScaler(); total time=  12.4s
# [CV] END classifier__colsample_bytree=0.6296178606936361, classifier__gamma=0.1792328642721363, classifier__learning_rate=0.03317381190502595, classifier__max_depth=9, classifier__min_child_weight=9, classifier__n_estimators=427, classifier__subsample=0.7797802696552814, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  51.0s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('categorical_pipeline',
#                                                                                Pipeline(steps=[('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               sparse_output=False))]),
#                                                                                ['country',
#                                                                                 'year',
#                                                                                 'location_type',
#                                                                                 'cellphone_access',
#                                                                                 'gender_of_respondent',
#                                                                                 'relationship_with_head',
#                                                                                 'marital_status',
#                                                                                 'education_level',
#                                                                                 'job_type']),
#                                                                               ('num...
#                                         'classifier__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x11fa8b190>,
#                                         'classifier__subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x11fab87d0>,
#                                         'preprocessor__numerical_pipeline__scaler': [StandardScaler(),
#                                                                                      MinMaxScaler(),
#                                                                                      RobustScaler()]},
#                    random_state=42, scoring='neg_mean_absolute_error',
#                    verbose=2)

# %%
best_model3 = search.best_estimator_

# %%
print(best_model3)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('categorical_pipeline',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['country', 'year',
#                                                    'location_type',
#                                                    'cellphone_access',
#                                                    'gender_of_respondent',
#                                                    'relationship_with_head',
#                                                    'marital_status',
#                                                    'education_level',
#                                                    'job_type']),
#                                                  ('numerical_pipeline',
#                                                   Pipeline(steps=[(...
#                                gpu_id=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.11618691666342727, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=4,
#                                max_leaves=None, min_child_weight=6, missing=nan,
#                                monotone_constraints=None, n_estimators=515,
#                                n_jobs=None, num_parallel_tree=None,
#                                predictor=None, random_state=42, ...))])

# %%
y_test_pred_xg_rnd_hyp = best_model3.predict(X_test)
y_test_pred_xg_rnd_hyp_probs = best_model3.predict_proba(X_test)[:, 1]

# %%
print(f"XGBoost with randomized tuning: MAE = {mean_absolute_error(y_test, y_test_pred_xg_rnd_hyp)}")
print(f"XGBoost with randomized tuning: roc curve score = {roc_auc_score(y_test, y_test_pred_xg_rnd_hyp_probs)}")
# Out:
# XGBoost with randomized tuning: MAE = 0.1190273762965482
# XGBoost with randomized tuning: roc curve score = 0.8658795272526676

# %% [markdown]
# ### XGBoost with grid search

# %%
param_grid = {
    "classifier__learning_rate": [0.11, 0.13],
    "classifier__max_depth": [4, 5],
    "classifier__min_child_weight": [6, 7],
    "classifier__n_estimators": [500, 550],
    "classifier__colsample_bytree": [0.83, 0.87],
    "classifier__gamma": [0.30, 0.40],
    "classifier__subsample": [0.80, 0.85]
}

# %%
grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring="neg_mean_absolute_error",
    cv=5,
    n_jobs=-1,
    verbose=0
)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('categorical_pipeline',
#                                                                          Pipeline(steps=[('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         sparse_output=False))]),
#                                                                          ['country',
#                                                                           'year',
#                                                                           'location_type',
#                                                                           'cellphone_access',
#                                                                           'gender_of_respondent',
#                                                                           'relationship_with_head',
#                                                                           'marital_status',
#                                                                           'education_level',
#                                                                           'job_type']),
#                                                                         ('numerical...
#                                                       num_parallel_tree=None,
#                                                       predictor=None,
#                                                       random_state=42, ...))]),
#              n_jobs=-1,
#              param_grid={'classifier__colsample_bytree': [0.83, 0.87],
#                          'classifier__gamma': [0.3, 0.4],
#                          'classifier__learning_rate': [0.11, 0.13],
#                          'classifier__max_depth': [4, 5],
#                          'classifier__min_child_weight': [6, 7],
#                          'classifier__n_estimators': [500, 550],
#                          'classifier__subsample': [0.8, 0.85]},
#              scoring='neg_mean_absolute_error')

# %%
best_model4 = grid_search.best_estimator_

# %%
y_test_pred_xg_grd_hyp = best_model4.predict(X_test)
y_test_pred_xg_grd_hyp_probs = best_model4.predict_proba(X_test)[:, 1]

# %%
print(f"XGBoost with grid tuning: MAE = {mean_absolute_error(y_test, y_test_pred_xg_grd_hyp)}")
print(f"XGBoost with grid tuning: roc curve score = {roc_auc_score(y_test, y_test_pred_xg_grd_hyp_probs)}")
# Out:
# XGBoost with grid tuning: MAE = 0.11953749362353341
# XGBoost with grid tuning: roc curve score = 0.8663522937060396

# %%
joblib.dump(best_model4, "xg_model.joblib")
# Out:
# ['xg_model.joblib']

# %% [markdown]
# ## Combining 3 models

# %%
y_test_pred_mode = (
    y_test_pred_rf_grd_hyp
    + y_test_pred_ad_rnd3_hyp
    + y_test_pred_xg_grd_hyp
    >= 2
).astype(int)

# %%
print(f"Mode: MAE = {mean_absolute_error(y_test, y_test_pred_mode)}")
# Out:
# Mode: MAE = 0.1168168678796123
# [CV] END classifier__colsample_bytree=0.9746919954946938, classifier__gamma=0.06876047207299663, classifier__learning_rate=0.0782132702100517, classifier__max_depth=3, classifier__min_child_weight=2, classifier__n_estimators=250, classifier__subsample=0.8165791895310264, preprocessor__numerical_pipeline__scaler=MinMaxScaler(); total time=  15.0s
# [CV] END classifier__colsample_bytree=0.7031766510860622, classifier__gamma=0.3299920230170895, classifier__learning_rate=0.17344444004024318, classifier__max_depth=3, classifier__min_child_weight=4, classifier__n_estimators=159, classifier__subsample=0.7043316699321636, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   7.7s
# [CV] END classifier__colsample_bytree=0.8903822715480958, classifier__gamma=0.44855512997628855, classifier__learning_rate=0.18741728485302347, classifier__max_depth=3, classifier__min_child_weight=8, classifier__n_estimators=215, classifier__subsample=0.6336559859980195, preprocessor__numerical_pipeline__scaler=MinMaxScaler(); total time=  12.1s
# [CV] END classifier__colsample_bytree=0.8675953018856915, classifier__gamma=0.29034331071822733, classifier__learning_rate=0.08445655331234861, classifier__max_depth=3, classifier__min_child_weight=3, classifier__n_estimators=252, classifier__subsample=0.6020246335384875, preprocessor__numerical_pipeline__scaler=MinMaxScaler(); total time=  13.9s
# [CV] END classifier__colsample_bytree=0.7301598792637071, classifier__gamma=0.37324570255901207, classifier__learning_rate=0.13992657980944295, classifier__max_depth=9, classifier__min_child_weight=3, classifier__n_estimators=500, classifier__subsample=0.7232243167409557, preprocessor__numerical_pipeline__scaler=RobustScaler(); total time= 1.2min
# [CV] END classifier__colsample_bytree=0.7737577462041715, classifier__gamma=0.17503920384733784, classifier__learning_rate=0.139020672406113, classifier__max_depth=9, classifier__min_child_weight=1, classifier__n_estimators=552, classifier__subsample=0.6920741072966221, preprocessor__numerical_pipeline__scaler=RobustScaler(); total time= 1.3min
# [CV] END classifier__colsample_bytree=0.7222788077148727, classifier__gamma=0.09545551557517301, classifier__learning_rate=0.06369497137803136, classifier__max_depth=5, classifier__min_child_weight=2, classifier__n_estimators=380, classifier__subsample=0.7578765867237889, preprocessor__numerical_pipeline__scaler=MinMaxScaler(); total time=  28.6s
# [CV] END classifier__colsample_bytree=0.8784119186699892, classifier__gamma=0.2850305850446825, classifier__learning_rate=0.02943529875415371, classifier__max_depth=9, classifier__min_child_weight=6, classifier__n_estimators=250, classifier__subsample=0.6560336060946096, preprocessor__numerical_pipeline__scaler=RobustScaler(); total time=  39.1s
# [CV] END classifier__colsample_bytree=0.9237444621914055, classifier__gamma=0.4050566973395904, classifier__learning_rate=0.18341446371602077, classifier__max_depth=7, classifier__min_child_weight=7, classifier__n_estimators=412, classifier__subsample=0.8511577659794545, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  52.8s
# [CV] END classifier__colsample_bytree=0.7753896492072347, classifier__gamma=0.3360130676475997, classifier__learning_rate=0.07563053349494639, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=413, classifier__subsample=0.9441618473246701, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  27.4s
# [CV] END classifier__colsample_bytree=0.7829060646454914, classifier__gamma=0.4210115375059907, classifier__learning_rate=0.04887600679897461, classifier__max_depth=8, classifier__min_child_weight=3, classifier__n_estimators=410, classifier__subsample=0.6553412369671205, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  52.0s
# [CV] END classifier__colsample_bytree=0.610140297366183, classifier__gamma=0.48132420733896253, classifier__learning_rate=0.17719602410244117, classifier__max_depth=3, classifier__min_child_weight=5, classifier__n_estimators=228, classifier__subsample=0.6693177280283383, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   9.5s
# [CV] END classifier__colsample_bytree=0.610140297366183, classifier__gamma=0.48132420733896253, classifier__learning_rate=0.17719602410244117, classifier__max_depth=3, classifier__min_child_weight=5, classifier__n_estimators=228, classifier__subsample=0.6693177280283383, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=   9.6s
# [CV] END classifier__colsample_bytree=0.7769408918924418, classifier__gamma=0.11989367957870162, classifier__learning_rate=0.02877465801625835, classifier__max_depth=3, classifier__min_child_weight=8, classifier__n_estimators=336, classifier__subsample=0.7119735587783771, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  16.9s
# [CV] END classifier__colsample_bytree=0.9031384441857476, classifier__gamma=0.007196744314877934, classifier__learning_rate=0.03321452810138325, classifier__max_depth=7, classifier__min_child_weight=1, classifier__n_estimators=193, classifier__subsample=0.9421842336044028, preprocessor__numerical_pipeline__scaler=StandardScaler(); total time=  24.7s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.8; total time=  34.3s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  39.7s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time=  39.4s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  37.4s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  38.1s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  43.3s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  46.0s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  42.7s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  46.8s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  48.0s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  35.2s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  44.8s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  36.3s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  38.1s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  38.8s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  42.3s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  46.7s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  42.6s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  46.6s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  46.4s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  34.7s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  37.4s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  34.3s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  38.1s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  37.4s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  42.8s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  46.7s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  42.8s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  46.6s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  45.7s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  34.5s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  37.9s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  33.7s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  38.3s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  36.0s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  41.8s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  44.7s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  45.3s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  45.9s
# [CV] END classifier__colsample_bytree=0.83, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  46.8s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  34.8s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  39.4s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  34.7s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  44.8s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  43.3s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  42.9s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  46.8s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  42.5s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  46.8s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  46.6s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  39.9s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time=  38.5s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  41.2s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time= 1.1min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.8; total time= 1.2min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time= 1.2min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time= 1.9min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.8; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time= 1.6min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time= 1.3min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time= 1.3min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time= 1.3min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time= 1.6min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time= 1.7min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  58.7s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  54.5s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  49.0s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  38.0s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time=  39.7s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  35.8s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  39.9s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.8; total time=  44.0s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  44.3s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time=  48.5s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  44.0s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  48.4s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  34.5s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  45.0s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  43.4s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  42.8s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time=  47.1s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  42.6s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  46.5s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  46.7s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  40.5s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time=  38.1s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.85; total time=  44.2s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time= 1.1min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.8; total time= 1.2min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.85; total time= 1.2min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.3, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time= 2.0min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.8; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time= 1.6min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.8; total time= 1.4min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time= 1.6min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.85; total time= 1.7min
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  51.8s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.11, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  52.3s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.8; total time=  36.6s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  38.0s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  39.6s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  35.7s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  40.1s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=4, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  39.3s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=500, classifier__subsample=0.85; total time=  44.3s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=6, classifier__n_estimators=550, classifier__subsample=0.8; total time=  48.4s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=500, classifier__subsample=0.8; total time=  44.0s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.8; total time=  48.4s
# [CV] END classifier__colsample_bytree=0.87, classifier__gamma=0.4, classifier__learning_rate=0.13, classifier__max_depth=5, classifier__min_child_weight=7, classifier__n_estimators=550, classifier__subsample=0.85; total time=  35.9s
